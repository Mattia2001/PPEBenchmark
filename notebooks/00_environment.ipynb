# %% [markdown]
# # PPE Benchmark Dataset
#
# Master Thesis
#
# Environment setup for the PPE Benchmark Dataset project.
#
# This notebook initializes the Colab environment, mounts Google Drive,
# installs all required dependencies and verifies the project structure.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

DRIVE_ROOT = Path(
    "/content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark"
)

print(DRIVE_ROOT)
print(DRIVE_ROOT.exists())

DATASETS_DIR = DRIVE_ROOT / "datasets"
PROCESSED_DIR = DRIVE_ROOT / "processed"
MODELS_DIR = DRIVE_ROOT / "models"
REPORTS_DIR = DRIVE_ROOT / "reports"
YOLO_DIR = DRIVE_ROOT / "yolo"
# Out:
# /content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark
# True

# %%
folders = [
    "datasets",
    "processed",
    "models",
    "reports",
    "yolo",
]

for folder in folders:
    path = DRIVE_ROOT / folder
    print(path, path.exists())
# Out:
# /content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark/datasets True
# /content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark/processed True
# /content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark/models True
# /content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark/reports True
# /content/drive/MyDrive/Master Thesis - Mattia Antonini/PPEBenchmark/yolo True

# %%
# !pip install -q ultralytics
# !pip install -q opencv-python
# !pip install -q pandas
# !pip install -q matplotlib
# !pip install -q tqdm
# !pip install -q pyyaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.0 MB/s eta 0:00:00

# %%
import ultralytics
import cv2
import pandas as pd
import yaml
import torch
import matplotlib

print("Ultralytics:", ultralytics.__version__)
print("OpenCV:", cv2.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics: 8.4.83
# OpenCV: 4.13.0
# Pandas: 2.2.2
# Matplotlib: 3.10.0
# CUDA available: True
# Tesla T4

# %%
import torch

print(torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
import platform
import sys

print(platform.platform())
print(sys.version)
# Out:
# Linux-6.6.122+-x86_64-with-glibc2.35
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
PROJECT_INFO = {
    "dataset": "PPE Benchmark",
    "framework": "Ultralytics YOLO",
    "environment": "Google Colab",
    "author": "Mattia",
}

# %%
import yaml
from pathlib import Path

CLASS_MAPPING_PATH = DRIVE_ROOT / "configs" / "class_mapping.yaml"

with open(CLASS_MAPPING_PATH, "r") as f:
    class_mapping = yaml.safe_load(f)

class_mapping["target_classes"]
# Out:
# {0: 'person', 1: 'helmet', 2: 'safety_vest', 3: 'gloves'}
